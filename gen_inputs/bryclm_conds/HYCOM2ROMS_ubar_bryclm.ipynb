# %%
############## Find Ubar ##################
# The purpose of this script is to use the output 
# from HYCOM2ROMS_u_currents_bryclm.py to find
# ubar and create the ubar clm and bry netcdf files
# using xesmf and the wonderful barotropic.f90 from
# model2roms Github repo


##########################################

# %%
# Load in the packages
import numpy as np
import xarray as xr
import xesmf as xe
#import ESMF
from datetime import datetime, timedelta
from cftime import num2date, date2num
from netCDF4 import Dataset

# %%
# Load in the data
# interpolated u currents 
# OG grid with 20 vertical layers
#u_currents = xr.open_dataset('/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/Attempt001/u_currents_clm_2019_2024_20vert_001.nc') #UPDATE PATH
# New grid with 30 vertical layers
u_currents = xr.open_dataset('/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/Attempt001/u_currents_clm_2019_2024_30vert_001.nc') #UPDATE PATH

# %%
# Vertical grid stuff
# OG grid with 20 vertical layers
#grid_vertical = xr.open_dataset('/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/ROMS_grid_depth_hpluszeta_2019_2024_20vert_001.nc')  #UPDATE PATH 
# New grid with 30 vertical layers
grid_vertical = xr.open_dataset('/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/ROMS_grid_depth_hpluszeta_2019_2024_30vert_001.nc')  #UPDATE PATH

# %%
# Need z_w to be positive so multiply by -1
z_w_pos = grid_vertical.z_w.values * (-1)
# check that this worked
print('z_w: ', grid_vertical.z_w[0,:,200,200].values)
print('z_w_pos: ', z_w_pos[0,:,200,200])
# Out:
# z_w:  [-1.15869655e+03 -1.12258029e+03 -1.07570948e+03 -1.01871115e+03
#  -9.53123137e+02 -8.81109101e+02 -8.05123757e+02 -7.27608278e+02
#  -6.50762289e+02 -5.76406240e+02 -5.05925367e+02 -4.40275321e+02
#  -3.80027264e+02 -3.25433060e+02 -2.76496226e+02 -2.33039321e+02
#  -1.94762741e+02 -1.61292875e+02 -1.32219593e+02 -1.07124064e+02
#  -8.55984753e+01 -6.72592483e+01 -5.17553191e+01 -3.87727897e+01
#  -2.80370470e+01 -1.93132059e+01 -1.24055328e+01 -7.15633815e+00
#  -3.44469054e+00 -1.18520306e+00 -3.27060431e-01]
# z_w_pos:  [1.15869655e+03 1.12258029e+03 1.07570948e+03 1.01871115e+03
#  9.53123137e+02 8.81109101e+02 8.05123757e+02 7.27608278e+02
#  6.50762289e+02 5.76406240e+02 5.05925367e+02 4.40275321e+02
#  3.80027264e+02 3.25433060e+02 2.76496226e+02 2.33039321e+02
#  1.94762741e+02 1.61292875e+02 1.32219593e+02 1.07124064e+02
#  8.55984753e+01 6.72592483e+01 5.17553191e+01 3.87727897e+01
#  2.80370470e+01 1.93132059e+01 1.24055328e+01 7.15633815e+00
#  3.44469054e+00 1.18520306e+00 3.27060431e-01]

# %%
# Read in the dimensions
#time_len = len(grid_vertical.time)
time_len = len(u_currents.v3d_time)
eta_rho_len = len(grid_vertical.eta_rho) # 206
xi_rho_len = len(grid_vertical.xi_rho) # 608
eta_u_len = len(grid_vertical.eta_u) # 206
xi_u_len = len(grid_vertical.xi_u) # 607
eta_v_len = len(grid_vertical.eta_v) # 205
xi_v_len = len(grid_vertical.xi_v) # 608

# Define other dimension lengths
# eta rho
Mp = len(grid_vertical.eta_rho)

# xi rho
Lp = len(grid_vertical.xi_rho)

# for u/v points 
Lm, Mm = (Lp-2), (Mp-2) #number/dimension of cells
L,  M  = Lm+1, Mm+1 #number/dimension of psi points

# srho
N = len(grid_vertical.s_rho)

# time
# this is done in grid_vertical so copy from there
time_tmp_len = np.copy(time_len)

# copy the actual time values - seconds since 2000-01-01
#time_tmp = grid_vertical.time.values
time_tmp = u_currents.v3d_time.values

# %%
# Set up the netcdf for the climatology 
# ------------------------------- Create the netCDF files ---------------------------

#name of file I am writing to
#vert_ubar_currents_clm = '/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/Attempt001/ubar_currents_clm_2019_2024_20vert_001.nc' #UPDATE PATH
vert_ubar_currents_clm = '/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/Attempt001/ubar_currents_clm_2019_2024_30vert_001.nc' #UPDATE PATH

#create file to write to
nc1 = Dataset(vert_ubar_currents_clm, 'w', format='NETCDF4')

#Global attributes
global_defaults = dict(gridname = 'KakAKgrd_shelf_big010_smooth006_thin_sponge.nc',
                      type = 'ROMS grid vertically interpolated HYCOM ubar currents climatology',
                      history = 'Created by Brianna Undzis',
                      Conventions = 'CF',
                      Institution = 'University of Colorado Boulder',
                      date = str(datetime.today()))

#create dictionary for model
d = {}
d = global_defaults

for att, value in d.items():
    setattr(nc1, att, value)

# %%
# Create dimensions
nc1.createDimension('xi_rho',  Lp)   # RHO
nc1.createDimension('eta_rho', Mp)
nc1.createDimension('s_rho', N)
nc1.createDimension('s_w',   (N+1))
nc1.createDimension('xi_u',    L)    # u
nc1.createDimension('eta_u',   Mp)
nc1.createDimension('v2d_time', None)
nc1.createDimension('one',     1)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'one', size = 1

# %%
# Create variables # this took several minutes (~9)
# --------------------
# Coordinate Variables
# --------------------
# xi rho
xi_rho = nc1.createVariable('xi_rho', 'd', ('xi_rho',), zlib=True)
xi_rho.long_name = 'xi coordinate of RHO-points'
xi_rho.standard_name = 'projection_xi_coordinate'
xi_rho.units = 'meter'
xi_rho_tmp = np.arange(0, Lp)
xi_rho[:] = xi_rho_tmp[:]

# eta rho
eta_rho = nc1.createVariable('eta_rho', 'd', ('eta_rho',), zlib=True)
eta_rho.long_name = 'eta coordinate of RHO-points'
eta_rho.standard_name = 'projection_eta_coordinate'
eta_rho.units = 'meter'
eta_rho_tmp = np.arange(0, Mp)
eta_rho[:] = eta_rho_tmp[:]

# xi u
xi_u = nc1.createVariable('xi_u', 'd', ('xi_u',), zlib = True)
xi_u.long_name = 'xi coordinate of U-points'
xi_u.standard_name = 'projection_xi_coordinate'
xi_u.units = 'meter'
xi_u[:]=np.arange(0,L)

# eta u
eta_u = nc1.createVariable('eta_u', 'd', ('eta_u',), zlib = True)
eta_u.long_name = 'eta coordinate of U-points'
eta_u.standard_name = 'projection_eta_coordinate'
eta_u.units = 'meter'
eta_u[:]=np.arange(0,Mp)

# s rho
s_rho = nc1.createVariable('s_rho', 'd', ('s_rho',), zlib=True)
s_rho.long_name = 's coordinate of RHO-points'
s_rho.standard_name = 'projection_s_coordinate'
s_rho.units = 'meter'
s_rho_tmp = np.arange(0, N)
s_rho[:] = s_rho_tmp[:]

# v2d_time (in seconds)
v2d_time_g = nc1.createVariable('v2d_time', None, ('v2d_time'), zlib=True)
v2d_time_g.long_name = 'seconds since 2000-01-01 00:00:00' #with initialization of 2000-01-01 00:00:00
v2d_time_g.units = 'second'
v2d_time_g.field = 'time, scalar, series'
v2d_time_g[:] = time_tmp[:]

# --------------------
# Boundary Currents
# --------------------

# ubar current
ubar_interp_g = nc1.createVariable('ubar', 'f8', ('v2d_time', 'eta_u', 'xi_u'), zlib=True)
ubar_interp_g.long_name = 'depth-averaged water u momentum'
ubar_interp_g.units = 'meter per second'

# %%
# Set up the netcdf for the boundary 
# ------------------------------- Create the netCDF file ---------------------------

#name of file I am writing to
#vert_ubar_currents_bry = '/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/Attempt001/ubar_currents_bry_2019_2024_20vert_001.nc' #UPDATE PATH
vert_ubar_currents_bry = '/pscratch/sd/b/bundzis/Beaufort_ROMS_2020_dvd_myroms_ice_scratch/Forcing_files/Bryclm/Attempt001/ubar_currents_bry_2019_2024_30vert_001.nc' #UPDATE PATH

#create file to write to
nc2 = Dataset(vert_ubar_currents_bry, 'w', format='NETCDF4')

#Global attributes
global_defaults = dict(gridname = 'KakAKgrd_shelf_big010_smooth006_thin_sponge.nc',
                      type = 'ROMS grid vertically interpolated HYCOM ubar currents boundary',
                      history = 'Created by Brianna Undzis',
                      Conventions = 'CF',
                      Institution = 'University of Colorado Boulder',
                      date = str(datetime.today()))

#create dictionary for model
d = {}
d = global_defaults

for att, value in d.items():
    setattr(nc2, att, value)

# %%
# Create dimensions
nc2.createDimension('xi_rho',  Lp)   # RHO
nc2.createDimension('eta_rho', Mp)
nc2.createDimension('s_rho', N)
nc2.createDimension('s_w',   (N+1))
nc2.createDimension('xi_u',    L)    # u
nc2.createDimension('eta_u',   Mp)
nc2.createDimension('v2d_time', None)
nc2.createDimension('one',     1)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'one', size = 1

# %%
# Create variables
# --------------------
# Coordinate Variables
# --------------------
# xi rho
xi_rho = nc2.createVariable('xi_rho', 'd', ('xi_rho',), zlib=True)
xi_rho.long_name = 'xi coordinate of RHO-points'
xi_rho.standard_name = 'projection_xi_coordinate'
xi_rho.units = 'meter'
xi_rho_tmp = np.arange(0, Lp)
xi_rho[:] = xi_rho_tmp[:]

# eta rho
eta_rho = nc2.createVariable('eta_rho', 'd', ('eta_rho',), zlib=True)
eta_rho.long_name = 'eta coordinate of RHO-points'
eta_rho.standard_name = 'projection_eta_coordinate'
eta_rho.units = 'meter'
eta_rho_tmp = np.arange(0, Mp)
eta_rho[:] = eta_rho_tmp[:]

# xi u
xi_u = nc2.createVariable('xi_u', 'd', ('xi_u',), zlib = True)
xi_u.long_name = 'xi coordinate of U-points'
xi_u.standard_name = 'projection_xi_coordinate'
xi_u.units = 'meter'
xi_u[:]=np.arange(0,L)

# eta u
eta_u = nc2.createVariable('eta_u', 'd', ('eta_u',), zlib = True)
eta_u.long_name = 'eta coordinate of U-points'
eta_u.standard_name = 'projection_eta_coordinate'
eta_u.units = 'meter'
eta_u[:]=np.arange(0,Mp)

# s rho
s_rho = nc2.createVariable('s_rho', 'd', ('s_rho',), zlib=True)
s_rho.long_name = 's coordinate of RHO-points'
s_rho.standard_name = 'projection_s_coordinate'
s_rho.units = 'meter'
s_rho_tmp = np.arange(0, N)

# v2d_time (in seconds)
v2d_time_g = nc2.createVariable('v2d_time', None, ('v2d_time'), zlib=True)
v2d_time_g.long_name = 'seconds since 2000-01-01 00:00:00' #with initialization of 2000-01-01 00:00:00
v2d_time_g.units = 'second'
v2d_time_g.field = 'ubar_time, scalar, series'
v2d_time_g[:] = time_tmp[:]

# --------------------
# Boundary Currents
# --------------------

# ubar current
# ubar_west
ubar_west_g = nc2.createVariable('ubar_west', 'f8', ('v2d_time', 'eta_u'), zlib=True)
ubar_west_g.long_name = 'depth-averaged water u momentum western boundary'
ubar_west_g.units = 'meter per second'

# ubar_north
ubar_north_g = nc2.createVariable('ubar_north', 'f8', ('v2d_time', 'xi_u'), zlib=True)
ubar_north_g.long_name = 'depth-averaged water u momentum northern boundary'
ubar_north_g.units = 'meter per second'

# ubar_east
ubar_east_g = nc2.createVariable('ubar_east', 'f8', ('v2d_time', 'eta_u'), zlib=True)
ubar_east_g.long_name = 'depth-averaged water u momentum eastern boundary'
ubar_east_g.units = 'meter per second'

# --------------------------------- End Netcdf set up -----------------------------------

# %%
# We need to interpolate z_w from rho points onto u points

# %%
# Make the rho grid 
ds_in_rho = grid_vertical.copy()
ds_in_rho['lat'] = (('eta_rho', 'xi_rho'), ds_in_rho.lat_rho.values)
ds_in_rho['lon'] = (('eta_rho', 'xi_rho'), ds_in_rho.lon_rho.values)

# Add masks 
# ex: ds["mask"] = xr.where(~np.isnan(ds["zeta"].isel(ocean_time=0)), 1, 0)
# Input grid (ROMS rho)
ds_in_rho['mask'] = (('eta_rho', 'xi_rho'), ds_in_rho.mask_rho.values)

# %%
# Make the u grid 
# Output grid (ROMS, but keeps HYCOM vertical levels)
#ds_out_u = grid_vertical
ds_out_u = grid_vertical.copy()
ds_out_u['lat'] = (('eta_u', 'xi_u'), ds_out_u.lat_u.values)
ds_out_u['lon'] = (('eta_u', 'xi_u'), ds_out_u.lon_u.values)

# Add masks
ds_out_u['mask'] = (('eta_u', 'xi_u'), ds_out_u.mask_u.values)

# %%
# Regrid from rho grid to u grid with the masks included and extrapolation used 
regridder_rho2u = xe.Regridder(ds_in_rho, ds_out_u, method="bilinear", extrap_method='nearest_s2d') #extrap_method="nearest_s2d"
regridder_rho2u
# Out:
# xESMF Regridder
# Regridding algorithm:       bilinear
# Weight filename:            bilinear_206x608_206x607.nc
# Reuse pre-computed weights? False
# Input grid shape:           (206, 608)
# Output grid shape:          (206, 607)
# Periodic in longitude?      False

# %%
# Make the rho2u regridder
# Use the weights we already have from  HYCOM2ROMS_u_currents_bryclm.py
# import the weights 
#rho2u_weights = '/projects/brun1463/ROMS/Kakak3_Alpine_2020/Scripts/Bryclm_conds/regrid_rho2u_weights.nc'
# Use them
#regridder_rho2u = xe.Regridder(ds_in_rho, ds_out_u, "bilinear", extrap_method='nearest_s2d', weights=rho2u_weights)

# %%
# Regrid z_w_pos 
dr_rho2u_zwpos = np.copy(z_w_pos)
dr_out_rho2u_zwpos = regridder_rho2u(dr_rho2u_zwpos)
#dr_out_rho2u_zwpos

# %%
# Now all our inputs are ready
# Compile and import model2roms barotropic.f90
# Use barotropic.f90 to calculate ubar
# from numpy import f2py
# with open('/projects/brun1463/ROMS/Kakak3_Alpine_2020/Scripts/Bryclm_conds/barotropic.f90') as sourcefile1:
#     sourcecode1 = sourcefile1.read()
# f2py.compile(sourcecode1, modulename='barotropic', extension='.f90')
import barotropic

# %%
# Call the function to calculate ubar
# Make an array to fill with the new values 
ubar_interp1 = np.empty((time_len, eta_u_len, xi_u_len))

# Loop through time
for t in range(time_len):
    # Print the time to see where we are
    print('t: ', t)
    
    # Call the function 
    ubar_interp1[t,:,:] = barotropic.velocity.ubar(u_currents.u[t,:,:,:].values, ubar_interp1[t,:,:], 
                                               z_w_pos[t,:,:,:], dr_out_rho2u_zwpos[t,:,:,:])
    
    # Save this to the netcdf
    # climatology 
    ubar_interp_g[t,:,:] = ubar_interp1[t,:,:]
    
    # boundary
    ubar_west_g[t,:] = ubar_interp1[t,:,0]
    ubar_north_g[t,:] = ubar_interp1[t,-1,:]
    ubar_east_g[t,:] = ubar_interp1[t,:,-1]
    
    # force save to netcdf
    nc1.sync()
    nc2.sync()

#print(ubar_interp1[0,200,200])
# Out:
# t:  0
#  ---> Started ubar calculations
# t:  1
#  ---> Started ubar calculations
# t:  2
#  ---> Started ubar calculations
# t:  3
#  ---> Started ubar calculations
# t:  4
#  ---> Started ubar calculations
# t:  5
#  ---> Started ubar calculations
# t:  6
#  ---> Started ubar calculations
# t:  7
#  ---> Started ubar calculations
# t:  8
#  ---> Started ubar calculations
# t:  9
#  ---> Started ubar calculations
# t:  10
#  ---> Started ubar calculations
# t:  11
#  ---> Started ubar calculations
# t:  12
#  ---> Started ubar calculations
# t:  13
#  ---> Started ubar calculations
# t:  14
#  ---> Started ubar calculations
# t:  15
#  ---> Started ubar calculations
# t:  16
#  ---> Started ubar calculations
# t:  17
#  ---> Started ubar calculations
# t:  18
#  ---> Started ubar calculations
# t:  19
#  ---> Started ubar calculations
# t:  20
#  ---> Started ubar calculations
# t:  21
#  ---> Started ubar calculations
# t:  22
#  ---> Started ubar calculations
# t:  23
#  ---> Started ubar calculations
# t:  24
#  ---> Started ubar calculations
# t:  25
#  ---> Started ubar calculations
# t:  26
#  ---> Started ubar calculations
# t:  27
#  ---> Started ubar calculations
# t:  28
#  ---> Started ubar calculations
# t:  29
#  ---> Started ubar calculations
# t:  30
#  ---> Started ubar calculations
# t:  31
#  ---> Started ubar calculations
# t:  32
#  ---> Started ubar calculations
# t:  33
#  ---> Started ubar calculations
# t:  34
#  ---> Started ubar calculations
# t:  35
#  ---> Started ubar calculations
# t:  36
#  ---> Started ubar calculations
# t:  37
#  ---> Started ubar calculations
# t:  38
#  ---> Started ubar calculations
# t:  39
#  ---> Started ubar calculations
# t:  40
#  ---> Started ubar calculations
# t:  41
#  ---> Started ubar calculations
# t:  42
#  ---> Started ubar calculations
# t:  43
#  ---> Started ubar calculations
# t:  44
#  ---> Started ubar calculations
# t:  45
#  ---> Started ubar calculations
# t:  46
#  ---> Started ubar calculations
# t:  47
#  ---> Started ubar calculations
# t:  48
#  ---> Started ubar calculations
# t:  49
#  ---> Started ubar calculations
# t:  50
#  ---> Started ubar calculations
# t:  51
#  ---> Started ubar calculations
# t:  52
#  ---> Started ubar calculations
# t:  53
#  ---> Started ubar calculations
# t:  54
#  ---> Started ubar calculations
# t:  55
#  ---> Started ubar calculations
# t:  56
#  ---> Started ubar calculations
# t:  57
#  ---> Started ubar calculations
# t:  58
#  ---> Started ubar calculations
# t:  59
#  ---> Started ubar calculations
# t:  60
#  ---> Started ubar calculations
# t:  61
#  ---> Started ubar calculations
# t:  62
#  ---> Started ubar calculations
# t:  63
#  ---> Started ubar calculations
# t:  64
#  ---> Started ubar calculations
# t:  65
#  ---> Started ubar calculations
# t:  66
#  ---> Started ubar calculations
# t:  67
#  ---> Started ubar calculations
# t:  68
#  ---> Started ubar calculations
# t:  69
#  ---> Started ubar calculations
# t:  70
#  ---> Started ubar calculations
# t:  71
#  ---> Started ubar calculations
# t:  72
#  ---> Started ubar calculations
# t:  73
#  ---> Started ubar calculations
# t:  74
#  ---> Started ubar calculations
# t:  75
#  ---> Started ubar calculations
# t:  76
#  ---> Started ubar calculations
# t:  77
#  ---> Started ubar calculations
# t:  78
#  ---> Started ubar calculations
# t:  79
#  ---> Started ubar calculations
# t:  80
#  ---> Started ubar calculations
# t:  81
#  ---> Started ubar calculations
# t:  82
#  ---> Started ubar calculations
# t:  83
#  ---> Started ubar calculations
# t:  84
#  ---> Started ubar calculations
# t:  85
#  ---> Started ubar calculations
# t:  86
#  ---> Started ubar calculations
# t:  87
#  ---> Started ubar calculations
# t:  88
#  ---> Started ubar calculations
# t:  89
#  ---> Started ubar calculations
# t:  90
#  ---> Started ubar calculations
# t:  91
#  ---> Started ubar calculations
# t:  92
#  ---> Started ubar calculations
# t:  93
#  ---> Started ubar calculations
# t:  94
#  ---> Started ubar calculations
# t:  95
#  ---> Started ubar calculations
# t:  96
#  ---> Started ubar calculations
# t:  97
#  ---> Started ubar calculations
# t:  98
#  ---> Started ubar calculations
# t:  99
#  ---> Started ubar calculations
# t:  100
#  ---> Started ubar calculations
# t:  101
#  ---> Started ubar calculations
# t:  102
#  ---> Started ubar calculations
# t:  103
#  ---> Started ubar calculations
# t:  104
#  ---> Started ubar calculations
# t:  105
#  ---> Started ubar calculations
# t:  106
#  ---> Started ubar calculations
# t:  107
#  ---> Started ubar calculations
# t:  108
#  ---> Started ubar calculations
# t:  109
#  ---> Started ubar calculations
# t:  110
#  ---> Started ubar calculations
# t:  111
#  ---> Started ubar calculations
# t:  112
#  ---> Started ubar calculations
# t:  113
#  ---> Started ubar calculations
# t:  114
#  ---> Started ubar calculations
# t:  115
#  ---> Started ubar calculations
# t:  116
#  ---> Started ubar calculations
# t:  117
#  ---> Started ubar calculations
# t:  118
#  ---> Started ubar calculations
# t:  119
#  ---> Started ubar calculations
# t:  120
#  ---> Started ubar calculations
# t:  121
#  ---> Started ubar calculations
# t:  122
#  ---> Started ubar calculations
# t:  123
#  ---> Started ubar calculations
# t:  124
#  ---> Started ubar calculations
# t:  125
#  ---> Started ubar calculations
# t:  126
#  ---> Started ubar calculations
# t:  127
#  ---> Started ubar calculations
# t:  128
#  ---> Started ubar calculations
# t:  129
#  ---> Started ubar calculations
# t:  130
#  ---> Started ubar calculations
# t:  131
#  ---> Started ubar calculations
# t:  132
#  ---> Started ubar calculations
# t:  133
#  ---> Started ubar calculations
# t:  134
#  ---> Started ubar calculations
# t:  135
#  ---> Started ubar calculations
# t:  136
#  ---> Started ubar calculations
# t:  137
#  ---> Started ubar calculations
# t:  138
#  ---> Started ubar calculations
# t:  139
#  ---> Started ubar calculations
# t:  140
#  ---> Started ubar calculations
# t:  141
#  ---> Started ubar calculations
# t:  142
#  ---> Started ubar calculations
# t:  143
#  ---> Started ubar calculations
# t:  144
#  ---> Started ubar calculations
# t:  145
#  ---> Started ubar calculations
# t:  146
#  ---> Started ubar calculations
# t:  147
#  ---> Started ubar calculations
# t:  148
#  ---> Started ubar calculations
# t:  149
#  ---> Started ubar calculations
# t:  150
#  ---> Started ubar calculations
# t:  151
#  ---> Started ubar calculations
# t:  152
#  ---> Started ubar calculations
# t:  153
#  ---> Started ubar calculations
# t:  154
#  ---> Started ubar calculations
# t:  155
#  ---> Started ubar calculations
# t:  156
#  ---> Started ubar calculations
# t:  157
#  ---> Started ubar calculations
# t:  158
#  ---> Started ubar calculations
# t:  159
#  ---> Started ubar calculations
# t:  160
#  ---> Started ubar calculations
# t:  161
#  ---> Started ubar calculations
# t:  162
#  ---> Started ubar calculations
# t:  163
#  ---> Started ubar calculations
# t:  164
#  ---> Started ubar calculations
# t:  165
#  ---> Started ubar calculations
# t:  166
#  ---> Started ubar calculations
# t:  167
#  ---> Started ubar calculations
# t:  168
#  ---> Started ubar calculations
# t:  169
#  ---> Started ubar calculations
# t:  170
#  ---> Started ubar calculations
# t:  171
#  ---> Started ubar calculations
# t:  172
#  ---> Started ubar calculations
# t:  173
#  ---> Started ubar calculations
# t:  174
#  ---> Started ubar calculations
# t:  175
#  ---> Started ubar calculations
# t:  176
#  ---> Started ubar calculations
# t:  177
#  ---> Started ubar calculations
# t:  178
#  ---> Started ubar calculations
# t:  179
#  ---> Started ubar calculations
# t:  180
#  ---> Started ubar calculations
# t:  181
#  ---> Started ubar calculations
# t:  182
#  ---> Started ubar calculations
# t:  183
#  ---> Started ubar calculations
# t:  184
#  ---> Started ubar calculations
# t:  185
#  ---> Started ubar calculations
# t:  186
#  ---> Started ubar calculations
# t:  187
#  ---> Started ubar calculations
# t:  188
#  ---> Started ubar calculations
# t:  189
#  ---> Started ubar calculations
# t:  190
#  ---> Started ubar calculations
# t:  191
#  ---> Started ubar calculations
# t:  192
#  ---> Started ubar calculations
# t:  193
#  ---> Started ubar calculations
# t:  194
#  ---> Started ubar calculations
# t:  195
#  ---> Started ubar calculations
# t:  196
#  ---> Started ubar calculations
# t:  197
#  ---> Started ubar calculations
# t:  198
#  ---> Started ubar calculations
# t:  199
#  ---> Started ubar calculations
# t:  200
#  ---> Started ubar calculations
# t:  201
#  ---> Started ubar calculations
# t:  202
#  ---> Started ubar calculations
# t:  203
#  ---> Started ubar calculations
# t:  204
#  ---> Started ubar calculations
# t:  205
#  ---> Started ubar calculations
# t:  206
#  ---> Started ubar calculations
# t:  207
#  ---> Started ubar calculations
# t:  208
#  ---> Started ubar calculations
# t:  209
#  ---> Started ubar calculations
# t:  210
#  ---> Started ubar calculations
# t:  211
#  ---> Started ubar calculations
# t:  212
#  ---> Started ubar calculations
# t:  213
#  ---> Started ubar calculations
# t:  214
#  ---> Started ubar calculations
# t:  215
#  ---> Started ubar calculations
# t:  216
#  ---> Started ubar calculations
# t:  217
#  ---> Started ubar calculations
# t:  218
#  ---> Started ubar calculations
# t:  219
#  ---> Started ubar calculations
# t:  220
#  ---> Started ubar calculations
# t:  221
#  ---> Started ubar calculations
# t:  222
#  ---> Started ubar calculations
# t:  223
#  ---> Started ubar calculations
# t:  224
#  ---> Started ubar calculations
# t:  225
#  ---> Started ubar calculations
# t:  226
#  ---> Started ubar calculations
# t:  227
#  ---> Started ubar calculations
# t:  228
#  ---> Started ubar calculations
# t:  229
#  ---> Started ubar calculations
# t:  230
#  ---> Started ubar calculations
# t:  231
#  ---> Started ubar calculations
# t:  232
#  ---> Started ubar calculations
# t:  233
#  ---> Started ubar calculations
# t:  234
#  ---> Started ubar calculations
# t:  235
#  ---> Started ubar calculations
# t:  236
#  ---> Started ubar calculations
# t:  237
#  ---> Started ubar calculations
# t:  238
#  ---> Started ubar calculations
# t:  239
#  ---> Started ubar calculations
# t:  240
#  ---> Started ubar calculations
# t:  241
#  ---> Started ubar calculations
# t:  242
#  ---> Started ubar calculations
# t:  243
#  ---> Started ubar calculations
# t:  244
#  ---> Started ubar calculations
# t:  245
#  ---> Started ubar calculations
# t:  246
#  ---> Started ubar calculations
# t:  247
#  ---> Started ubar calculations
# t:  248
#  ---> Started ubar calculations
# t:  249
#  ---> Started ubar calculations
# t:  250
#  ---> Started ubar calculations
# t:  251
#  ---> Started ubar calculations
# t:  252
#  ---> Started ubar calculations
# t:  253
#  ---> Started ubar calculations
# t:  254
#  ---> Started ubar calculations
# t:  255
#  ---> Started ubar calculations
# t:  256
#  ---> Started ubar calculations
# t:  257
#  ---> Started ubar calculations
# t:  258
#  ---> Started ubar calculations
# t:  259
#  ---> Started ubar calculations
# t:  260
#  ---> Started ubar calculations
# t:  261
#  ---> Started ubar calculations
# t:  262
#  ---> Started ubar calculations
# t:  263
#  ---> Started ubar calculations
# t:  264
#  ---> Started ubar calculations
# t:  265
#  ---> Started ubar calculations
# t:  266
#  ---> Started ubar calculations
# t:  267
#  ---> Started ubar calculations
# t:  268
#  ---> Started ubar calculations
# t:  269
#  ---> Started ubar calculations
# t:  270
#  ---> Started ubar calculations
# t:  271
#  ---> Started ubar calculations
# t:  272
#  ---> Started ubar calculations
# t:  273
#  ---> Started ubar calculations
# t:  274
#  ---> Started ubar calculations
# t:  275
#  ---> Started ubar calculations
# t:  276
#  ---> Started ubar calculations
# t:  277
#  ---> Started ubar calculations
# t:  278
#  ---> Started ubar calculations
# t:  279
#  ---> Started ubar calculations
# t:  280
#  ---> Started ubar calculations
# t:  281
#  ---> Started ubar calculations
# t:  282
#  ---> Started ubar calculations
# t:  283
#  ---> Started ubar calculations
# t:  284
#  ---> Started ubar calculations
# t:  285
#  ---> Started ubar calculations
# t:  286
#  ---> Started ubar calculations
# t:  287
#  ---> Started ubar calculations
# t:  288
#  ---> Started ubar calculations
# t:  289
#  ---> Started ubar calculations
# t:  290
#  ---> Started ubar calculations
# t:  291
#  ---> Started ubar calculations
# t:  292
#  ---> Started ubar calculations
# t:  293
#  ---> Started ubar calculations
# t:  294
#  ---> Started ubar calculations
# t:  295
#  ---> Started ubar calculations
# t:  296
#  ---> Started ubar calculations
# t:  297
#  ---> Started ubar calculations
# t:  298
#  ---> Started ubar calculations
# t:  299
#  ---> Started ubar calculations
# t:  300
#  ---> Started ubar calculations
# t:  301
#  ---> Started ubar calculations
# t:  302
#  ---> Started ubar calculations
# t:  303
#  ---> Started ubar calculations
# t:  304
#  ---> Started ubar calculations
# t:  305
#  ---> Started ubar calculations
# t:  306
#  ---> Started ubar calculations
# t:  307
#  ---> Started ubar calculations
# t:  308
#  ---> Started ubar calculations
# t:  309
#  ---> Started ubar calculations
# t:  310
#  ---> Started ubar calculations
# t:  311
#  ---> Started ubar calculations
# t:  312
#  ---> Started ubar calculations
# t:  313
#  ---> Started ubar calculations
# t:  314
#  ---> Started ubar calculations
# t:  315
#  ---> Started ubar calculations
# t:  316
#  ---> Started ubar calculations
# t:  317
#  ---> Started ubar calculations
# t:  318
#  ---> Started ubar calculations
# t:  319
#  ---> Started ubar calculations
# t:  320
#  ---> Started ubar calculations
# t:  321
#  ---> Started ubar calculations
# t:  322
#  ---> Started ubar calculations
# t:  323
#  ---> Started ubar calculations
# t:  324
#  ---> Started ubar calculations
# t:  325
#  ---> Started ubar calculations
# t:  326
#  ---> Started ubar calculations
# t:  327
#  ---> Started ubar calculations
# t:  328
#  ---> Started ubar calculations
# t:  329
#  ---> Started ubar calculations
# t:  330
#  ---> Started ubar calculations
# t:  331
#  ---> Started ubar calculations
# t:  332
#  ---> Started ubar calculations
# t:  333
#  ---> Started ubar calculations
# t:  334
#  ---> Started ubar calculations
# t:  335
#  ---> Started ubar calculations
# t:  336
#  ---> Started ubar calculations
# t:  337
#  ---> Started ubar calculations
# t:  338
#  ---> Started ubar calculations
# t:  339
#  ---> Started ubar calculations
# t:  340
#  ---> Started ubar calculations
# t:  341
#  ---> Started ubar calculations
# t:  342
#  ---> Started ubar calculations
# t:  343
#  ---> Started ubar calculations
# t:  344
#  ---> Started ubar calculations
# t:  345
#  ---> Started ubar calculations
# t:  346
#  ---> Started ubar calculations
# t:  347
#  ---> Started ubar calculations
# t:  348
#  ---> Started ubar calculations
# t:  349
#  ---> Started ubar calculations
# t:  350
#  ---> Started ubar calculations
# t:  351
#  ---> Started ubar calculations
# t:  352
#  ---> Started ubar calculations
# t:  353
#  ---> Started ubar calculations
# t:  354
#  ---> Started ubar calculations
# t:  355
#  ---> Started ubar calculations
# t:  356
#  ---> Started ubar calculations
# t:  357
#  ---> Started ubar calculations
# t:  358
#  ---> Started ubar calculations
# t:  359
#  ---> Started ubar calculations
# t:  360
#  ---> Started ubar calculations
# t:  361
#  ---> Started ubar calculations
# t:  362
#  ---> Started ubar calculations
# t:  363
#  ---> Started ubar calculations
# t:  364
#  ---> Started ubar calculations
# t:  365
#  ---> Started ubar calculations
# t:  366
#  ---> Started ubar calculations
# t:  367
#  ---> Started ubar calculations
# t:  368
#  ---> Started ubar calculations
# t:  369
#  ---> Started ubar calculations
# t:  370
#  ---> Started ubar calculations
# t:  371
#  ---> Started ubar calculations
# t:  372
#  ---> Started ubar calculations
# t:  373
#  ---> Started ubar calculations
# t:  374
#  ---> Started ubar calculations
# t:  375
#  ---> Started ubar calculations
# t:  376
#  ---> Started ubar calculations
# t:  377
#  ---> Started ubar calculations
# t:  378
#  ---> Started ubar calculations
# t:  379
#  ---> Started ubar calculations
# t:  380
#  ---> Started ubar calculations
# t:  381
#  ---> Started ubar calculations
# t:  382
#  ---> Started ubar calculations
# t:  383
#  ---> Started ubar calculations
# t:  384
#  ---> Started ubar calculations
# t:  385
#  ---> Started ubar calculations
# t:  386
#  ---> Started ubar calculations
# t:  387
#  ---> Started ubar calculations
# t:  388
#  ---> Started ubar calculations
# t:  389
#  ---> Started ubar calculations
# t:  390
#  ---> Started ubar calculations
# t:  391
#  ---> Started ubar calculations
# t:  392
#  ---> Started ubar calculations
# t:  393
#  ---> Started ubar calculations
# t:  394
#  ---> Started ubar calculations
# t:  395
#  ---> Started ubar calculations
# t:  396
#  ---> Started ubar calculations
# t:  397
#  ---> Started ubar calculations
# t:  398
#  ---> Started ubar calculations
# t:  399
#  ---> Started ubar calculations
# t:  400
#  ---> Started ubar calculations
# t:  401
#  ---> Started ubar calculations
# t:  402
#  ---> Started ubar calculations
# t:  403
#  ---> Started ubar calculations
# t:  404
#  ---> Started ubar calculations
# t:  405
#  ---> Started ubar calculations
# t:  406
#  ---> Started ubar calculations
# t:  407
#  ---> Started ubar calculations
# t:  408
#  ---> Started ubar calculations
# t:  409
#  ---> Started ubar calculations
# t:  410
#  ---> Started ubar calculations
# t:  411
#  ---> Started ubar calculations
# t:  412
#  ---> Started ubar calculations
# t:  413
#  ---> Started ubar calculations
# t:  414
#  ---> Started ubar calculations
# t:  415
#  ---> Started ubar calculations
# t:  416
#  ---> Started ubar calculations
# t:  417
#  ---> Started ubar calculations
# t:  418
#  ---> Started ubar calculations
# t:  419
#  ---> Started ubar calculations
# t:  420
#  ---> Started ubar calculations
# t:  421
#  ---> Started ubar calculations
# t:  422
#  ---> Started ubar calculations
# t:  423
#  ---> Started ubar calculations
# t:  424
#  ---> Started ubar calculations
# t:  425
#  ---> Started ubar calculations
# t:  426
#  ---> Started ubar calculations
# t:  427
#  ---> Started ubar calculations
# t:  428
#  ---> Started ubar calculations
# t:  429
#  ---> Started ubar calculations
# t:  430
#  ---> Started ubar calculations
# t:  431
#  ---> Started ubar calculations
# t:  432
#  ---> Started ubar calculations
# t:  433
#  ---> Started ubar calculations
# t:  434
#  ---> Started ubar calculations
# t:  435
#  ---> Started ubar calculations
# t:  436
#  ---> Started ubar calculations
# t:  437
#  ---> Started ubar calculations
# t:  438
#  ---> Started ubar calculations
# t:  439
#  ---> Started ubar calculations
# t:  440
#  ---> Started ubar calculations
# t:  441
#  ---> Started ubar calculations
# t:  442
#  ---> Started ubar calculations
# t:  443
#  ---> Started ubar calculations
# t:  444
#  ---> Started ubar calculations
# t:  445
#  ---> Started ubar calculations
# t:  446
#  ---> Started ubar calculations
# t:  447
#  ---> Started ubar calculations
# t:  448
#  ---> Started ubar calculations
# t:  449
#  ---> Started ubar calculations
# t:  450
#  ---> Started ubar calculations
# t:  451
#  ---> Started ubar calculations
# t:  452
#  ---> Started ubar calculations
# t:  453
#  ---> Started ubar calculations
# t:  454
#  ---> Started ubar calculations
# t:  455
#  ---> Started ubar calculations
# t:  456
#  ---> Started ubar calculations
# t:  457
#  ---> Started ubar calculations
# t:  458
#  ---> Started ubar calculations
# t:  459
#  ---> Started ubar calculations
# t:  460
#  ---> Started ubar calculations
# t:  461
#  ---> Started ubar calculations
# t:  462
#  ---> Started ubar calculations
# t:  463
#  ---> Started ubar calculations
# t:  464
#  ---> Started ubar calculations
# t:  465
#  ---> Started ubar calculations
# t:  466
#  ---> Started ubar calculations
# t:  467
#  ---> Started ubar calculations
# t:  468
#  ---> Started ubar calculations
# t:  469
#  ---> Started ubar calculations
# t:  470
#  ---> Started ubar calculations
# t:  471
#  ---> Started ubar calculations
# t:  472
#  ---> Started ubar calculations
# t:  473
#  ---> Started ubar calculations
# t:  474
#  ---> Started ubar calculations
# t:  475
#  ---> Started ubar calculations
# t:  476
#  ---> Started ubar calculations
# t:  477
#  ---> Started ubar calculations
# t:  478
#  ---> Started ubar calculations
# t:  479
#  ---> Started ubar calculations
# t:  480
#  ---> Started ubar calculations
# t:  481
#  ---> Started ubar calculations
# t:  482
#  ---> Started ubar calculations
# t:  483
#  ---> Started ubar calculations
# t:  484
#  ---> Started ubar calculations
# t:  485
#  ---> Started ubar calculations
# t:  486
#  ---> Started ubar calculations
# t:  487
#  ---> Started ubar calculations
# t:  488
#  ---> Started ubar calculations
# t:  489
#  ---> Started ubar calculations
# t:  490
#  ---> Started ubar calculations
# t:  491
#  ---> Started ubar calculations
# t:  492
#  ---> Started ubar calculations
# t:  493
#  ---> Started ubar calculations
# t:  494
#  ---> Started ubar calculations
# t:  495
#  ---> Started ubar calculations
# t:  496
#  ---> Started ubar calculations
# t:  497
#  ---> Started ubar calculations
# t:  498
#  ---> Started ubar calculations
# t:  499
#  ---> Started ubar calculations
# t:  500
#  ---> Started ubar calculations
# t:  501
#  ---> Started ubar calculations
# t:  502
#  ---> Started ubar calculations
# t:  503
#  ---> Started ubar calculations
# t:  504
#  ---> Started ubar calculations
# t:  505
#  ---> Started ubar calculations
# t:  506
#  ---> Started ubar calculations
# t:  507
#  ---> Started ubar calculations
# t:  508
#  ---> Started ubar calculations
# t:  509
#  ---> Started ubar calculations
# t:  510
#  ---> Started ubar calculations
# t:  511
#  ---> Started ubar calculations
# t:  512
#  ---> Started ubar calculations
# t:  513
#  ---> Started ubar calculations
# t:  514
#  ---> Started ubar calculations
# t:  515
#  ---> Started ubar calculations
# t:  516
#  ---> Started ubar calculations
# t:  517
#  ---> Started ubar calculations
# t:  518
#  ---> Started ubar calculations
# t:  519
#  ---> Started ubar calculations
# t:  520
#  ---> Started ubar calculations
# t:  521
#  ---> Started ubar calculations
# t:  522
#  ---> Started ubar calculations
# t:  523
#  ---> Started ubar calculations
# t:  524
#  ---> Started ubar calculations
# t:  525
#  ---> Started ubar calculations
# t:  526
#  ---> Started ubar calculations
# t:  527
#  ---> Started ubar calculations
# t:  528
#  ---> Started ubar calculations
# t:  529
#  ---> Started ubar calculations
# t:  530
#  ---> Started ubar calculations
# t:  531
#  ---> Started ubar calculations
# t:  532
#  ---> Started ubar calculations
# t:  533
#  ---> Started ubar calculations
# t:  534
#  ---> Started ubar calculations
# t:  535
#  ---> Started ubar calculations
# t:  536
#  ---> Started ubar calculations
# t:  537
#  ---> Started ubar calculations
# t:  538
#  ---> Started ubar calculations
# t:  539
#  ---> Started ubar calculations
# t:  540
#  ---> Started ubar calculations
# t:  541
#  ---> Started ubar calculations
# t:  542
#  ---> Started ubar calculations
# t:  543
#  ---> Started ubar calculations
# t:  544
#  ---> Started ubar calculations
# t:  545
#  ---> Started ubar calculations
# t:  546
#  ---> Started ubar calculations
# t:  547
#  ---> Started ubar calculations
# t:  548
#  ---> Started ubar calculations
# t:  549
#  ---> Started ubar calculations
# t:  550
#  ---> Started ubar calculations
# t:  551
#  ---> Started ubar calculations
# t:  552
#  ---> Started ubar calculations
# t:  553
#  ---> Started ubar calculations
# t:  554
#  ---> Started ubar calculations
# t:  555
#  ---> Started ubar calculations
# t:  556
#  ---> Started ubar calculations
# t:  557
#  ---> Started ubar calculations
# t:  558
#  ---> Started ubar calculations
# t:  559
#  ---> Started ubar calculations
# t:  560
#  ---> Started ubar calculations
# t:  561
#  ---> Started ubar calculations
# t:  562
#  ---> Started ubar calculations
# t:  563
#  ---> Started ubar calculations
# t:  564
#  ---> Started ubar calculations
# t:  565
#  ---> Started ubar calculations
# t:  566
#  ---> Started ubar calculations
# t:  567
#  ---> Started ubar calculations
# t:  568
#  ---> Started ubar calculations
# t:  569
#  ---> Started ubar calculations
# t:  570
#  ---> Started ubar calculations
# t:  571
#  ---> Started ubar calculations
# t:  572
#  ---> Started ubar calculations
# t:  573
#  ---> Started ubar calculations
# t:  574
#  ---> Started ubar calculations
# t:  575
#  ---> Started ubar calculations
# t:  576
#  ---> Started ubar calculations
# t:  577
#  ---> Started ubar calculations
# t:  578
#  ---> Started ubar calculations
# t:  579
#  ---> Started ubar calculations
# t:  580
#  ---> Started ubar calculations
# t:  581
#  ---> Started ubar calculations
# t:  582
#  ---> Started ubar calculations
# t:  583
#  ---> Started ubar calculations
# t:  584
#  ---> Started ubar calculations
# t:  585
#  ---> Started ubar calculations
# t:  586
#  ---> Started ubar calculations
# t:  587
#  ---> Started ubar calculations
# t:  588
#  ---> Started ubar calculations
# t:  589
#  ---> Started ubar calculations
# t:  590
#  ---> Started ubar calculations
# t:  591
#  ---> Started ubar calculations
# t:  592
#  ---> Started ubar calculations
# t:  593
#  ---> Started ubar calculations
# t:  594
#  ---> Started ubar calculations
# t:  595
#  ---> Started ubar calculations
# t:  596
#  ---> Started ubar calculations
# t:  597
#  ---> Started ubar calculations
# t:  598
#  ---> Started ubar calculations
# t:  599
#  ---> Started ubar calculations
# t:  600
#  ---> Started ubar calculations
# t:  601
#  ---> Started ubar calculations
# t:  602
#  ---> Started ubar calculations
# t:  603
#  ---> Started ubar calculations
# t:  604
#  ---> Started ubar calculations
# t:  605
#  ---> Started ubar calculations
# t:  606
#  ---> Started ubar calculations
# t:  607
#  ---> Started ubar calculations
# t:  608
#  ---> Started ubar calculations
# t:  609
#  ---> Started ubar calculations
# t:  610
#  ---> Started ubar calculations
# t:  611
#  ---> Started ubar calculations
# t:  612
#  ---> Started ubar calculations
# t:  613
#  ---> Started ubar calculations
# t:  614
#  ---> Started ubar calculations
# t:  615
#  ---> Started ubar calculations
# t:  616
#  ---> Started ubar calculations
# t:  617
#  ---> Started ubar calculations
# t:  618
#  ---> Started ubar calculations
# t:  619
#  ---> Started ubar calculations
# t:  620
#  ---> Started ubar calculations
# t:  621
#  ---> Started ubar calculations
# t:  622
#  ---> Started ubar calculations
# t:  623
#  ---> Started ubar calculations
# t:  624
#  ---> Started ubar calculations
# t:  625
#  ---> Started ubar calculations
# t:  626
#  ---> Started ubar calculations
# t:  627
#  ---> Started ubar calculations
# t:  628
#  ---> Started ubar calculations
# t:  629
#  ---> Started ubar calculations
# t:  630
#  ---> Started ubar calculations
# t:  631
#  ---> Started ubar calculations
# t:  632
#  ---> Started ubar calculations
# t:  633
#  ---> Started ubar calculations
# t:  634
#  ---> Started ubar calculations
# t:  635
#  ---> Started ubar calculations
# t:  636
#  ---> Started ubar calculations
# t:  637
#  ---> Started ubar calculations
# t:  638
#  ---> Started ubar calculations
# t:  639
#  ---> Started ubar calculations
# t:  640
#  ---> Started ubar calculations
# t:  641
#  ---> Started ubar calculations
# t:  642
#  ---> Started ubar calculations
# t:  643
#  ---> Started ubar calculations
# t:  644
#  ---> Started ubar calculations
# t:  645
#  ---> Started ubar calculations
# t:  646
#  ---> Started ubar calculations
# t:  647
#  ---> Started ubar calculations
# t:  648
#  ---> Started ubar calculations
# t:  649
#  ---> Started ubar calculations
# t:  650
#  ---> Started ubar calculations
# t:  651
#  ---> Started ubar calculations
# t:  652
#  ---> Started ubar calculations
# t:  653
#  ---> Started ubar calculations
# t:  654
#  ---> Started ubar calculations
# t:  655
#  ---> Started ubar calculations
# t:  656
#  ---> Started ubar calculations
# t:  657
#  ---> Started ubar calculations
# t:  658
#  ---> Started ubar calculations
# t:  659
#  ---> Started ubar calculations
# t:  660
#  ---> Started ubar calculations
# t:  661
#  ---> Started ubar calculations
# t:  662
#  ---> Started ubar calculations
# t:  663
#  ---> Started ubar calculations
# t:  664
#  ---> Started ubar calculations
# t:  665
#  ---> Started ubar calculations
# t:  666
#  ---> Started ubar calculations
# t:  667
#  ---> Started ubar calculations
# t:  668
#  ---> Started ubar calculations
# t:  669
#  ---> Started ubar calculations
# t:  670
#  ---> Started ubar calculations
# t:  671
#  ---> Started ubar calculations
# t:  672
#  ---> Started ubar calculations
# t:  673
#  ---> Started ubar calculations
# t:  674
#  ---> Started ubar calculations
# t:  675
#  ---> Started ubar calculations
# t:  676
#  ---> Started ubar calculations
# t:  677
#  ---> Started ubar calculations
# t:  678
#  ---> Started ubar calculations
# t:  679
#  ---> Started ubar calculations
# t:  680
#  ---> Started ubar calculations
# t:  681
#  ---> Started ubar calculations
# t:  682
#  ---> Started ubar calculations
# t:  683
#  ---> Started ubar calculations
# t:  684
#  ---> Started ubar calculations
# t:  685
#  ---> Started ubar calculations
# t:  686
#  ---> Started ubar calculations
# t:  687
#  ---> Started ubar calculations
# t:  688
#  ---> Started ubar calculations
# t:  689
#  ---> Started ubar calculations
# t:  690
#  ---> Started ubar calculations
# t:  691
#  ---> Started ubar calculations
# t:  692
#  ---> Started ubar calculations
# t:  693
#  ---> Started ubar calculations
# t:  694
#  ---> Started ubar calculations
# t:  695
#  ---> Started ubar calculations
# t:  696
#  ---> Started ubar calculations
# t:  697
#  ---> Started ubar calculations
# t:  698
#  ---> Started ubar calculations
# t:  699
#  ---> Started ubar calculations
# t:  700
#  ---> Started ubar calculations
# t:  701
#  ---> Started ubar calculations
# t:  702
#  ---> Started ubar calculations
# t:  703
#  ---> Started ubar calculations
# t:  704
#  ---> Started ubar calculations
# t:  705
#  ---> Started ubar calculations
# t:  706
#  ---> Started ubar calculations
# t:  707
#  ---> Started ubar calculations
# t:  708
#  ---> Started ubar calculations
# t:  709
#  ---> Started ubar calculations
# t:  710
#  ---> Started ubar calculations
# t:  711
#  ---> Started ubar calculations
# t:  712
#  ---> Started ubar calculations
# t:  713
#  ---> Started ubar calculations
# t:  714
#  ---> Started ubar calculations
# t:  715
#  ---> Started ubar calculations
# t:  716
#  ---> Started ubar calculations
# t:  717
#  ---> Started ubar calculations
# t:  718
#  ---> Started ubar calculations
# t:  719
#  ---> Started ubar calculations
# t:  720
#  ---> Started ubar calculations
# t:  721
#  ---> Started ubar calculations
# t:  722
#  ---> Started ubar calculations
# t:  723
#  ---> Started ubar calculations
# t:  724
#  ---> Started ubar calculations
# t:  725
#  ---> Started ubar calculations
# t:  726
#  ---> Started ubar calculations
# t:  727
#  ---> Started ubar calculations
# t:  728
#  ---> Started ubar calculations
# t:  729
#  ---> Started ubar calculations
# t:  730
#  ---> Started ubar calculations
# t:  731
#  ---> Started ubar calculations
# t:  732
#  ---> Started ubar calculations
# t:  733
#  ---> Started ubar calculations
# t:  734
#  ---> Started ubar calculations
# t:  735
#  ---> Started ubar calculations
# t:  736
#  ---> Started ubar calculations
# t:  737
#  ---> Started ubar calculations
# t:  738
#  ---> Started ubar calculations
# t:  739
#  ---> Started ubar calculations
# t:  740
#  ---> Started ubar calculations
# t:  741
#  ---> Started ubar calculations
# t:  742
#  ---> Started ubar calculations
# t:  743
#  ---> Started ubar calculations
# t:  744
#  ---> Started ubar calculations
# t:  745
#  ---> Started ubar calculations
# t:  746
#  ---> Started ubar calculations
# t:  747
#  ---> Started ubar calculations
# t:  748
#  ---> Started ubar calculations
# t:  749
#  ---> Started ubar calculations
# t:  750
#  ---> Started ubar calculations
# t:  751
#  ---> Started ubar calculations
# t:  752
#  ---> Started ubar calculations
# t:  753
#  ---> Started ubar calculations
# t:  754
#  ---> Started ubar calculations
# t:  755
#  ---> Started ubar calculations
# t:  756
#  ---> Started ubar calculations
# t:  757
#  ---> Started ubar calculations
# t:  758
#  ---> Started ubar calculations
# t:  759
#  ---> Started ubar calculations
# t:  760
#  ---> Started ubar calculations
# t:  761
#  ---> Started ubar calculations
# t:  762
#  ---> Started ubar calculations
# t:  763
#  ---> Started ubar calculations
# t:  764
#  ---> Started ubar calculations
# t:  765
#  ---> Started ubar calculations
# t:  766
#  ---> Started ubar calculations
# t:  767
#  ---> Started ubar calculations
# t:  768
#  ---> Started ubar calculations
# t:  769
#  ---> Started ubar calculations
# t:  770
#  ---> Started ubar calculations
# t:  771
#  ---> Started ubar calculations
# t:  772
#  ---> Started ubar calculations
# t:  773
#  ---> Started ubar calculations
# t:  774
#  ---> Started ubar calculations
# t:  775
#  ---> Started ubar calculations
# t:  776
#  ---> Started ubar calculations
# t:  777
#  ---> Started ubar calculations
# t:  778
#  ---> Started ubar calculations
# t:  779
#  ---> Started ubar calculations
# t:  780
#  ---> Started ubar calculations
# t:  781
#  ---> Started ubar calculations
# t:  782
#  ---> Started ubar calculations
# t:  783
#  ---> Started ubar calculations
# t:  784
#  ---> Started ubar calculations
# t:  785
#  ---> Started ubar calculations
# t:  786
#  ---> Started ubar calculations
# t:  787
#  ---> Started ubar calculations
# t:  788
#  ---> Started ubar calculations
# t:  789
#  ---> Started ubar calculations
# t:  790
#  ---> Started ubar calculations
# t:  791
#  ---> Started ubar calculations
# t:  792
#  ---> Started ubar calculations
# t:  793
#  ---> Started ubar calculations
# t:  794
#  ---> Started ubar calculations
# t:  795
#  ---> Started ubar calculations
# t:  796
#  ---> Started ubar calculations
# t:  797
#  ---> Started ubar calculations
# t:  798
#  ---> Started ubar calculations
# t:  799
#  ---> Started ubar calculations
# t:  800
#  ---> Started ubar calculations
# t:  801
#  ---> Started ubar calculations
# t:  802
#  ---> Started ubar calculations
# t:  803
#  ---> Started ubar calculations
# t:  804
#  ---> Started ubar calculations
# t:  805
#  ---> Started ubar calculations
# t:  806
#  ---> Started ubar calculations
# t:  807
#  ---> Started ubar calculations
# t:  808
#  ---> Started ubar calculations
# t:  809
#  ---> Started ubar calculations
# t:  810
#  ---> Started ubar calculations
# t:  811
#  ---> Started ubar calculations
# t:  812
#  ---> Started ubar calculations
# t:  813
#  ---> Started ubar calculations
# t:  814
#  ---> Started ubar calculations
# t:  815
#  ---> Started ubar calculations
# t:  816
#  ---> Started ubar calculations
# t:  817
#  ---> Started ubar calculations
# t:  818
#  ---> Started ubar calculations
# t:  819
#  ---> Started ubar calculations
# t:  820
#  ---> Started ubar calculations
# t:  821
#  ---> Started ubar calculations
# t:  822
#  ---> Started ubar calculations
# t:  823
#  ---> Started ubar calculations
# t:  824
#  ---> Started ubar calculations
# t:  825
#  ---> Started ubar calculations
# t:  826
#  ---> Started ubar calculations
# t:  827
#  ---> Started ubar calculations
# t:  828
#  ---> Started ubar calculations
# t:  829
#  ---> Started ubar calculations
# t:  830
#  ---> Started ubar calculations
# t:  831
#  ---> Started ubar calculations
# t:  832
#  ---> Started ubar calculations
# t:  833
#  ---> Started ubar calculations
# t:  834
#  ---> Started ubar calculations
# t:  835
#  ---> Started ubar calculations
# t:  836
#  ---> Started ubar calculations
# t:  837
#  ---> Started ubar calculations
# t:  838
#  ---> Started ubar calculations
# t:  839
#  ---> Started ubar calculations
# t:  840
#  ---> Started ubar calculations
# t:  841
#  ---> Started ubar calculations
# t:  842
#  ---> Started ubar calculations
# t:  843
#  ---> Started ubar calculations
# t:  844
#  ---> Started ubar calculations
# t:  845
#  ---> Started ubar calculations
# t:  846
#  ---> Started ubar calculations
# t:  847
#  ---> Started ubar calculations
# t:  848
#  ---> Started ubar calculations
# t:  849
#  ---> Started ubar calculations
# t:  850
#  ---> Started ubar calculations
# t:  851
#  ---> Started ubar calculations
# t:  852
#  ---> Started ubar calculations
# t:  853
#  ---> Started ubar calculations
# t:  854
#  ---> Started ubar calculations
# t:  855
#  ---> Started ubar calculations
# t:  856
#  ---> Started ubar calculations
# t:  857
#  ---> Started ubar calculations
# t:  858
#  ---> Started ubar calculations
# t:  859
#  ---> Started ubar calculations
# t:  860
#  ---> Started ubar calculations
# t:  861
#  ---> Started ubar calculations
# t:  862
#  ---> Started ubar calculations
# t:  863
#  ---> Started ubar calculations
# t:  864
#  ---> Started ubar calculations
# t:  865
#  ---> Started ubar calculations
# t:  866
#  ---> Started ubar calculations
# t:  867
#  ---> Started ubar calculations
# t:  868
#  ---> Started ubar calculations
# t:  869
#  ---> Started ubar calculations
# t:  870
#  ---> Started ubar calculations
# t:  871
#  ---> Started ubar calculations
# t:  872
#  ---> Started ubar calculations
# t:  873
#  ---> Started ubar calculations
# t:  874
#  ---> Started ubar calculations
# t:  875
#  ---> Started ubar calculations
# t:  876
#  ---> Started ubar calculations
# t:  877
#  ---> Started ubar calculations
# t:  878
#  ---> Started ubar calculations
# t:  879
#  ---> Started ubar calculations
# t:  880
#  ---> Started ubar calculations
# t:  881
#  ---> Started ubar calculations
# t:  882
#  ---> Started ubar calculations
# t:  883
#  ---> Started ubar calculations
# t:  884
#  ---> Started ubar calculations
# t:  885
#  ---> Started ubar calculations
# t:  886
#  ---> Started ubar calculations
# t:  887
#  ---> Started ubar calculations
# t:  888
#  ---> Started ubar calculations
# t:  889
#  ---> Started ubar calculations
# t:  890
#  ---> Started ubar calculations
# t:  891
#  ---> Started ubar calculations
# t:  892
#  ---> Started ubar calculations
# t:  893
#  ---> Started ubar calculations
# t:  894
#  ---> Started ubar calculations
# t:  895
#  ---> Started ubar calculations
# t:  896
#  ---> Started ubar calculations
# t:  897
#  ---> Started ubar calculations
# t:  898
#  ---> Started ubar calculations
# t:  899
#  ---> Started ubar calculations
# t:  900
#  ---> Started ubar calculations
# t:  901
#  ---> Started ubar calculations
# t:  902
#  ---> Started ubar calculations
# t:  903
#  ---> Started ubar calculations
# t:  904
#  ---> Started ubar calculations
# t:  905
#  ---> Started ubar calculations
# t:  906
#  ---> Started ubar calculations
# t:  907
#  ---> Started ubar calculations
# t:  908
#  ---> Started ubar calculations
# t:  909
#  ---> Started ubar calculations
# t:  910
#  ---> Started ubar calculations
# t:  911
#  ---> Started ubar calculations
# t:  912
#  ---> Started ubar calculations
# t:  913
#  ---> Started ubar calculations
# t:  914
#  ---> Started ubar calculations
# t:  915
#  ---> Started ubar calculations
# t:  916
#  ---> Started ubar calculations
# t:  917
#  ---> Started ubar calculations
# t:  918
#  ---> Started ubar calculations
# t:  919
#  ---> Started ubar calculations
# t:  920
#  ---> Started ubar calculations
# t:  921
#  ---> Started ubar calculations
# t:  922
#  ---> Started ubar calculations
# t:  923
#  ---> Started ubar calculations
# t:  924
#  ---> Started ubar calculations
# t:  925
#  ---> Started ubar calculations
# t:  926
#  ---> Started ubar calculations
# t:  927
#  ---> Started ubar calculations
# t:  928
#  ---> Started ubar calculations
# t:  929
#  ---> Started ubar calculations
# t:  930
#  ---> Started ubar calculations
# t:  931
#  ---> Started ubar calculations
# t:  932
#  ---> Started ubar calculations
# t:  933
#  ---> Started ubar calculations
# t:  934
#  ---> Started ubar calculations
# t:  935
#  ---> Started ubar calculations
# t:  936
#  ---> Started ubar calculations
# t:  937
#  ---> Started ubar calculations
# t:  938
#  ---> Started ubar calculations
# t:  939
#  ---> Started ubar calculations
# t:  940
#  ---> Started ubar calculations
# t:  941
#  ---> Started ubar calculations
# t:  942
#  ---> Started ubar calculations
# t:  943
#  ---> Started ubar calculations
# t:  944
#  ---> Started ubar calculations
# t:  945
#  ---> Started ubar calculations
# t:  946
#  ---> Started ubar calculations
# t:  947
#  ---> Started ubar calculations
# t:  948
#  ---> Started ubar calculations
# t:  949
#  ---> Started ubar calculations
# t:  950
#  ---> Started ubar calculations
# t:  951
#  ---> Started ubar calculations
# t:  952
#  ---> Started ubar calculations
# t:  953
#  ---> Started ubar calculations
# t:  954
#  ---> Started ubar calculations
# t:  955
#  ---> Started ubar calculations
# t:  956
#  ---> Started ubar calculations
# t:  957
#  ---> Started ubar calculations
# t:  958
#  ---> Started ubar calculations
# t:  959
#  ---> Started ubar calculations
# t:  960
#  ---> Started ubar calculations
# t:  961
#  ---> Started ubar calculations
# t:  962
#  ---> Started ubar calculations
# t:  963
#  ---> Started ubar calculations
# t:  964
#  ---> Started ubar calculations
# t:  965
#  ---> Started ubar calculations
# t:  966
#  ---> Started ubar calculations
# t:  967
#  ---> Started ubar calculations
# t:  968
#  ---> Started ubar calculations
# t:  969
#  ---> Started ubar calculations
# t:  970
#  ---> Started ubar calculations
# t:  971
#  ---> Started ubar calculations
# t:  972
#  ---> Started ubar calculations
# t:  973
#  ---> Started ubar calculations
# t:  974
#  ---> Started ubar calculations
# t:  975
#  ---> Started ubar calculations
# t:  976
#  ---> Started ubar calculations
# t:  977
#  ---> Started ubar calculations
# t:  978
#  ---> Started ubar calculations
# t:  979
#  ---> Started ubar calculations
# t:  980
#  ---> Started ubar calculations
# t:  981
#  ---> Started ubar calculations
# t:  982
#  ---> Started ubar calculations
# t:  983
#  ---> Started ubar calculations
# t:  984
#  ---> Started ubar calculations
# t:  985
#  ---> Started ubar calculations
# t:  986
#  ---> Started ubar calculations
# t:  987
#  ---> Started ubar calculations
# t:  988
#  ---> Started ubar calculations
# t:  989
#  ---> Started ubar calculations
# t:  990
#  ---> Started ubar calculations
# t:  991
#  ---> Started ubar calculations
# t:  992
#  ---> Started ubar calculations
# t:  993
#  ---> Started ubar calculations
# t:  994
#  ---> Started ubar calculations
# t:  995
#  ---> Started ubar calculations
# t:  996
#  ---> Started ubar calculations
# t:  997
#  ---> Started ubar calculations
# t:  998
#  ---> Started ubar calculations
# t:  999
#  ---> Started ubar calculations
# t:  1000
#  ---> Started ubar calculations
# t:  1001
#  ---> Started ubar calculations
# t:  1002
#  ---> Started ubar calculations
# t:  1003
#  ---> Started ubar calculations
# t:  1004
#  ---> Started ubar calculations
# t:  1005
#  ---> Started ubar calculations
# t:  1006
#  ---> Started ubar calculations
# t:  1007
#  ---> Started ubar calculations
# t:  1008
#  ---> Started ubar calculations
# t:  1009
#  ---> Started ubar calculations
# t:  1010
#  ---> Started ubar calculations
# t:  1011
#  ---> Started ubar calculations
# t:  1012
#  ---> Started ubar calculations
# t:  1013
#  ---> Started ubar calculations
# t:  1014
#  ---> Started ubar calculations
# t:  1015
#  ---> Started ubar calculations
# t:  1016
#  ---> Started ubar calculations
# t:  1017
#  ---> Started ubar calculations
# t:  1018
#  ---> Started ubar calculations
# t:  1019
#  ---> Started ubar calculations
# t:  1020
#  ---> Started ubar calculations
# t:  1021
#  ---> Started ubar calculations
# t:  1022
#  ---> Started ubar calculations
# t:  1023
#  ---> Started ubar calculations
# t:  1024
#  ---> Started ubar calculations
# t:  1025
#  ---> Started ubar calculations
# t:  1026
#  ---> Started ubar calculations
# t:  1027
#  ---> Started ubar calculations
# t:  1028
#  ---> Started ubar calculations
# t:  1029
#  ---> Started ubar calculations
# t:  1030
#  ---> Started ubar calculations
# t:  1031
#  ---> Started ubar calculations
# t:  1032
#  ---> Started ubar calculations
# t:  1033
#  ---> Started ubar calculations
# t:  1034
#  ---> Started ubar calculations
# t:  1035
#  ---> Started ubar calculations
# t:  1036
#  ---> Started ubar calculations
# t:  1037
#  ---> Started ubar calculations
# t:  1038
#  ---> Started ubar calculations
# t:  1039
#  ---> Started ubar calculations
# t:  1040
#  ---> Started ubar calculations
# t:  1041
#  ---> Started ubar calculations
# t:  1042
#  ---> Started ubar calculations
# t:  1043
#  ---> Started ubar calculations
# t:  1044
#  ---> Started ubar calculations
# t:  1045
#  ---> Started ubar calculations
# t:  1046
#  ---> Started ubar calculations
# t:  1047
#  ---> Started ubar calculations
# t:  1048
#  ---> Started ubar calculations
# t:  1049
#  ---> Started ubar calculations
# t:  1050
#  ---> Started ubar calculations
# t:  1051
#  ---> Started ubar calculations
# t:  1052
#  ---> Started ubar calculations
# t:  1053
#  ---> Started ubar calculations
# t:  1054
#  ---> Started ubar calculations
# t:  1055
#  ---> Started ubar calculations
# t:  1056
#  ---> Started ubar calculations
# t:  1057
#  ---> Started ubar calculations
# t:  1058
#  ---> Started ubar calculations
# t:  1059
#  ---> Started ubar calculations
# t:  1060
#  ---> Started ubar calculations
# t:  1061
#  ---> Started ubar calculations
# t:  1062
#  ---> Started ubar calculations
# t:  1063
#  ---> Started ubar calculations
# t:  1064
#  ---> Started ubar calculations
# t:  1065
#  ---> Started ubar calculations
# t:  1066
#  ---> Started ubar calculations
# t:  1067
#  ---> Started ubar calculations
# t:  1068
#  ---> Started ubar calculations
# t:  1069
#  ---> Started ubar calculations
# t:  1070
#  ---> Started ubar calculations
# t:  1071
#  ---> Started ubar calculations
# t:  1072
#  ---> Started ubar calculations
# t:  1073
#  ---> Started ubar calculations
# t:  1074
#  ---> Started ubar calculations
# t:  1075
#  ---> Started ubar calculations
# t:  1076
#  ---> Started ubar calculations
# t:  1077
#  ---> Started ubar calculations
# t:  1078
#  ---> Started ubar calculations
# t:  1079
#  ---> Started ubar calculations
# t:  1080
#  ---> Started ubar calculations
# t:  1081
#  ---> Started ubar calculations
# t:  1082
#  ---> Started ubar calculations
# t:  1083
#  ---> Started ubar calculations
# t:  1084
#  ---> Started ubar calculations
# t:  1085
#  ---> Started ubar calculations
# t:  1086
#  ---> Started ubar calculations
# t:  1087
#  ---> Started ubar calculations
# t:  1088
#  ---> Started ubar calculations
# t:  1089
#  ---> Started ubar calculations
# t:  1090
#  ---> Started ubar calculations
# t:  1091
#  ---> Started ubar calculations
# t:  1092
#  ---> Started ubar calculations
# t:  1093
#  ---> Started ubar calculations
# t:  1094
#  ---> Started ubar calculations
# t:  1095
#  ---> Started ubar calculations
# t:  1096
#  ---> Started ubar calculations
# t:  1097
#  ---> Started ubar calculations
# t:  1098
#  ---> Started ubar calculations
# t:  1099
#  ---> Started ubar calculations
# t:  1100
#  ---> Started ubar calculations
# t:  1101
#  ---> Started ubar calculations
# t:  1102
#  ---> Started ubar calculations
# t:  1103
#  ---> Started ubar calculations
# t:  1104
#  ---> Started ubar calculations
# t:  1105
#  ---> Started ubar calculations
# t:  1106
#  ---> Started ubar calculations
# t:  1107
#  ---> Started ubar calculations
# t:  1108
#  ---> Started ubar calculations
# t:  1109
#  ---> Started ubar calculations
# t:  1110
#  ---> Started ubar calculations
# t:  1111
#  ---> Started ubar calculations
# t:  1112
#  ---> Started ubar calculations
# t:  1113
#  ---> Started ubar calculations
# t:  1114
#  ---> Started ubar calculations
# t:  1115
#  ---> Started ubar calculations
# t:  1116
#  ---> Started ubar calculations
# t:  1117
#  ---> Started ubar calculations
# t:  1118
#  ---> Started ubar calculations
# t:  1119
#  ---> Started ubar calculations
# t:  1120
#  ---> Started ubar calculations
# t:  1121
#  ---> Started ubar calculations
# t:  1122
#  ---> Started ubar calculations
# t:  1123
#  ---> Started ubar calculations
# t:  1124
#  ---> Started ubar calculations
# t:  1125
#  ---> Started ubar calculations
# t:  1126
#  ---> Started ubar calculations
# t:  1127
#  ---> Started ubar calculations
# t:  1128
#  ---> Started ubar calculations
# t:  1129
#  ---> Started ubar calculations
# t:  1130
#  ---> Started ubar calculations
# t:  1131
#  ---> Started ubar calculations
# t:  1132
#  ---> Started ubar calculations
# t:  1133
#  ---> Started ubar calculations
# t:  1134
#  ---> Started ubar calculations
# t:  1135
#  ---> Started ubar calculations
# t:  1136
#  ---> Started ubar calculations
# t:  1137
#  ---> Started ubar calculations
# t:  1138
#  ---> Started ubar calculations
# t:  1139
#  ---> Started ubar calculations
# t:  1140
#  ---> Started ubar calculations
# t:  1141
#  ---> Started ubar calculations
# t:  1142
#  ---> Started ubar calculations
# t:  1143
#  ---> Started ubar calculations
# t:  1144
#  ---> Started ubar calculations
# t:  1145
#  ---> Started ubar calculations
# t:  1146
#  ---> Started ubar calculations
# t:  1147
#  ---> Started ubar calculations
# t:  1148
#  ---> Started ubar calculations
# t:  1149
#  ---> Started ubar calculations
# t:  1150
#  ---> Started ubar calculations
# t:  1151
#  ---> Started ubar calculations
# t:  1152
#  ---> Started ubar calculations
# t:  1153
#  ---> Started ubar calculations
# t:  1154
#  ---> Started ubar calculations
# t:  1155
#  ---> Started ubar calculations
# t:  1156
#  ---> Started ubar calculations
# t:  1157
#  ---> Started ubar calculations
# t:  1158
#  ---> Started ubar calculations
# t:  1159
#  ---> Started ubar calculations
# t:  1160
#  ---> Started ubar calculations
# t:  1161
#  ---> Started ubar calculations
# t:  1162
#  ---> Started ubar calculations
# t:  1163
#  ---> Started ubar calculations
# t:  1164
#  ---> Started ubar calculations
# t:  1165
#  ---> Started ubar calculations
# t:  1166
#  ---> Started ubar calculations
# t:  1167
#  ---> Started ubar calculations
# t:  1168
#  ---> Started ubar calculations
# t:  1169
#  ---> Started ubar calculations
# t:  1170
#  ---> Started ubar calculations
# t:  1171
#  ---> Started ubar calculations
# t:  1172
#  ---> Started ubar calculations
# t:  1173
#  ---> Started ubar calculations
# t:  1174
#  ---> Started ubar calculations
# t:  1175
#  ---> Started ubar calculations
# t:  1176
#  ---> Started ubar calculations
# t:  1177
#  ---> Started ubar calculations
# t:  1178
#  ---> Started ubar calculations
# t:  1179
#  ---> Started ubar calculations
# t:  1180
#  ---> Started ubar calculations
# t:  1181
#  ---> Started ubar calculations
# t:  1182
#  ---> Started ubar calculations
# t:  1183
#  ---> Started ubar calculations
# t:  1184
#  ---> Started ubar calculations
# t:  1185
#  ---> Started ubar calculations
# t:  1186
#  ---> Started ubar calculations
# t:  1187
#  ---> Started ubar calculations
# t:  1188
#  ---> Started ubar calculations
# t:  1189
#  ---> Started ubar calculations
# t:  1190
#  ---> Started ubar calculations
# t:  1191
#  ---> Started ubar calculations
# t:  1192
#  ---> Started ubar calculations
# t:  1193
#  ---> Started ubar calculations
# t:  1194
#  ---> Started ubar calculations
# t:  1195
#  ---> Started ubar calculations
# t:  1196
#  ---> Started ubar calculations
# t:  1197
# ...
# t:  1685
#  ---> Started ubar calculations
# t:  1686
#  ---> Started ubar calculations
# t:  1687
#  ---> Started ubar calculations
# t:  1688
#  ---> Started ubar calculations
# t:  1689
#  ---> Started ubar calculations
# t:  1690
#  ---> Started ubar calculations
# t:  1691
#  ---> Started ubar calculations
# t:  1692
#  ---> Started ubar calculations
# t:  1693
#  ---> Started ubar calculations
# t:  1694
#  ---> Started ubar calculations
# t:  1695
#  ---> Started ubar calculations
# t:  1696
#  ---> Started ubar calculations
# t:  1697
#  ---> Started ubar calculations
# t:  1698
#  ---> Started ubar calculations
# t:  1699
#  ---> Started ubar calculations
# t:  1700
#  ---> Started ubar calculations
# t:  1701
#  ---> Started ubar calculations
# t:  1702
#  ---> Started ubar calculations
# t:  1703
#  ---> Started ubar calculations
# t:  1704
#  ---> Started ubar calculations
# t:  1705
#  ---> Started ubar calculations
# t:  1706
#  ---> Started ubar calculations
# t:  1707
#  ---> Started ubar calculations
# t:  1708
#  ---> Started ubar calculations
# t:  1709
#  ---> Started ubar calculations
# t:  1710
#  ---> Started ubar calculations
# t:  1711
#  ---> Started ubar calculations
# t:  1712
#  ---> Started ubar calculations
# t:  1713
#  ---> Started ubar calculations
# t:  1714
#  ---> Started ubar calculations
# t:  1715
#  ---> Started ubar calculations
# t:  1716
#  ---> Started ubar calculations
# t:  1717
#  ---> Started ubar calculations
# t:  1718
#  ---> Started ubar calculations
# t:  1719
#  ---> Started ubar calculations
# t:  1720
#  ---> Started ubar calculations
# t:  1721
#  ---> Started ubar calculations
# t:  1722
#  ---> Started ubar calculations
# t:  1723
#  ---> Started ubar calculations
# t:  1724
#  ---> Started ubar calculations
# t:  1725
#  ---> Started ubar calculations
# t:  1726
#  ---> Started ubar calculations
# t:  1727
#  ---> Started ubar calculations
# t:  1728
#  ---> Started ubar calculations
# t:  1729
#  ---> Started ubar calculations
# t:  1730
#  ---> Started ubar calculations
# t:  1731
#  ---> Started ubar calculations
# t:  1732
#  ---> Started ubar calculations
# t:  1733
#  ---> Started ubar calculations
# t:  1734
#  ---> Started ubar calculations
# t:  1735
#  ---> Started ubar calculations
# t:  1736
#  ---> Started ubar calculations
# t:  1737
#  ---> Started ubar calculations
# t:  1738
#  ---> Started ubar calculations
# t:  1739
#  ---> Started ubar calculations
# t:  1740
#  ---> Started ubar calculations
# t:  1741
#  ---> Started ubar calculations
# t:  1742
#  ---> Started ubar calculations
# t:  1743
#  ---> Started ubar calculations
# t:  1744
#  ---> Started ubar calculations
# t:  1745
#  ---> Started ubar calculations
# t:  1746
#  ---> Started ubar calculations
# t:  1747
#  ---> Started ubar calculations
# t:  1748
#  ---> Started ubar calculations
# t:  1749
#  ---> Started ubar calculations
# t:  1750
#  ---> Started ubar calculations
# t:  1751
#  ---> Started ubar calculations
# t:  1752
#  ---> Started ubar calculations
# t:  1753
#  ---> Started ubar calculations
# t:  1754
#  ---> Started ubar calculations
# t:  1755
#  ---> Started ubar calculations
# t:  1756
#  ---> Started ubar calculations
# t:  1757
#  ---> Started ubar calculations
# t:  1758
#  ---> Started ubar calculations
# t:  1759
#  ---> Started ubar calculations
# t:  1760
#  ---> Started ubar calculations
# t:  1761
#  ---> Started ubar calculations
# t:  1762
#  ---> Started ubar calculations
# t:  1763
#  ---> Started ubar calculations
# t:  1764
#  ---> Started ubar calculations
# t:  1765
#  ---> Started ubar calculations
# t:  1766
#  ---> Started ubar calculations
# t:  1767
#  ---> Started ubar calculations
# t:  1768
#  ---> Started ubar calculations
# t:  1769
#  ---> Started ubar calculations
# t:  1770
#  ---> Started ubar calculations
# t:  1771
#  ---> Started ubar calculations
# t:  1772
#  ---> Started ubar calculations
# t:  1773
#  ---> Started ubar calculations
# t:  1774
#  ---> Started ubar calculations
# t:  1775
#  ---> Started ubar calculations
# t:  1776
#  ---> Started ubar calculations
# t:  1777
#  ---> Started ubar calculations
# t:  1778
#  ---> Started ubar calculations
# t:  1779
#  ---> Started ubar calculations
# t:  1780
#  ---> Started ubar calculations
# t:  1781
#  ---> Started ubar calculations
# t:  1782
#  ---> Started ubar calculations
# t:  1783
#  ---> Started ubar calculations
# t:  1784
#  ---> Started ubar calculations
# t:  1785
#  ---> Started ubar calculations
# t:  1786
#  ---> Started ubar calculations
# t:  1787
#  ---> Started ubar calculations
# t:  1788
#  ---> Started ubar calculations
# t:  1789
#  ---> Started ubar calculations
# t:  1790
#  ---> Started ubar calculations
# t:  1791
#  ---> Started ubar calculations
# t:  1792
#  ---> Started ubar calculations
# t:  1793
#  ---> Started ubar calculations
# t:  1794
#  ---> Started ubar calculations
# t:  1795
#  ---> Started ubar calculations
# t:  1796
#  ---> Started ubar calculations
# t:  1797
#  ---> Started ubar calculations
# t:  1798
#  ---> Started ubar calculations
# t:  1799
#  ---> Started ubar calculations
# t:  1800
#  ---> Started ubar calculations
# t:  1801
#  ---> Started ubar calculations
# t:  1802
#  ---> Started ubar calculations
# t:  1803
#  ---> Started ubar calculations
# t:  1804
#  ---> Started ubar calculations
# t:  1805
#  ---> Started ubar calculations
# t:  1806
#  ---> Started ubar calculations
# t:  1807
#  ---> Started ubar calculations
# t:  1808
#  ---> Started ubar calculations
# t:  1809
#  ---> Started ubar calculations
# t:  1810
#  ---> Started ubar calculations
# t:  1811
#  ---> Started ubar calculations
# t:  1812
#  ---> Started ubar calculations
# t:  1813
#  ---> Started ubar calculations
# t:  1814
#  ---> Started ubar calculations
# t:  1815
#  ---> Started ubar calculations
# t:  1816
#  ---> Started ubar calculations
# t:  1817
#  ---> Started ubar calculations
# t:  1818
#  ---> Started ubar calculations
# t:  1819
#  ---> Started ubar calculations
# t:  1820
#  ---> Started ubar calculations
# t:  1821
#  ---> Started ubar calculations
# t:  1822
#  ---> Started ubar calculations
# t:  1823
#  ---> Started ubar calculations
# t:  1824
#  ---> Started ubar calculations
# t:  1825
#  ---> Started ubar calculations
# t:  1826
#  ---> Started ubar calculations
# t:  1827
#  ---> Started ubar calculations
# t:  1828
#  ---> Started ubar calculations
# t:  1829
#  ---> Started ubar calculations
# t:  1830
#  ---> Started ubar calculations
# t:  1831
#  ---> Started ubar calculations
# t:  1832
#  ---> Started ubar calculations
# t:  1833
#  ---> Started ubar calculations
# t:  1834
#  ---> Started ubar calculations
# t:  1835
#  ---> Started ubar calculations
# t:  1836
#  ---> Started ubar calculations
# t:  1837
#  ---> Started ubar calculations
# t:  1838
#  ---> Started ubar calculations
# t:  1839
#  ---> Started ubar calculations
# t:  1840
#  ---> Started ubar calculations
# t:  1841
#  ---> Started ubar calculations
# t:  1842
#  ---> Started ubar calculations
# t:  1843
#  ---> Started ubar calculations
# t:  1844
#  ---> Started ubar calculations
# t:  1845
#  ---> Started ubar calculations
# t:  1846
#  ---> Started ubar calculations
# t:  1847
#  ---> Started ubar calculations
# t:  1848
#  ---> Started ubar calculations
# t:  1849
#  ---> Started ubar calculations
# t:  1850
#  ---> Started ubar calculations
# t:  1851
#  ---> Started ubar calculations
# t:  1852
#  ---> Started ubar calculations
# t:  1853
#  ---> Started ubar calculations
# t:  1854
#  ---> Started ubar calculations
# t:  1855
#  ---> Started ubar calculations
# t:  1856
#  ---> Started ubar calculations
# t:  1857
#  ---> Started ubar calculations
# t:  1858
#  ---> Started ubar calculations
# t:  1859
#  ---> Started ubar calculations
# t:  1860
#  ---> Started ubar calculations
# t:  1861
#  ---> Started ubar calculations
# t:  1862
#  ---> Started ubar calculations
# t:  1863
#  ---> Started ubar calculations
# t:  1864
#  ---> Started ubar calculations
# t:  1865
#  ---> Started ubar calculations
# t:  1866
#  ---> Started ubar calculations
# t:  1867
#  ---> Started ubar calculations
# t:  1868
#  ---> Started ubar calculations
# t:  1869
#  ---> Started ubar calculations
# t:  1870
#  ---> Started ubar calculations
# t:  1871
#  ---> Started ubar calculations
# t:  1872
#  ---> Started ubar calculations
# t:  1873
#  ---> Started ubar calculations
# t:  1874
#  ---> Started ubar calculations
# t:  1875
#  ---> Started ubar calculations
# t:  1876
#  ---> Started ubar calculations
# t:  1877
#  ---> Started ubar calculations
# t:  1878
#  ---> Started ubar calculations
# t:  1879
#  ---> Started ubar calculations
# t:  1880
#  ---> Started ubar calculations
# t:  1881
#  ---> Started ubar calculations
# t:  1882
#  ---> Started ubar calculations
# t:  1883
#  ---> Started ubar calculations
# t:  1884
#  ---> Started ubar calculations
# t:  1885
#  ---> Started ubar calculations
# t:  1886
#  ---> Started ubar calculations
# t:  1887
#  ---> Started ubar calculations
# t:  1888
#  ---> Started ubar calculations
# t:  1889
#  ---> Started ubar calculations
# t:  1890
#  ---> Started ubar calculations
# t:  1891
#  ---> Started ubar calculations
# t:  1892
#  ---> Started ubar calculations
# t:  1893
#  ---> Started ubar calculations
# t:  1894
#  ---> Started ubar calculations
# t:  1895
#  ---> Started ubar calculations
# t:  1896
#  ---> Started ubar calculations
# t:  1897
#  ---> Started ubar calculations
# t:  1898
#  ---> Started ubar calculations
# t:  1899
#  ---> Started ubar calculations
# t:  1900
#  ---> Started ubar calculations
# t:  1901
#  ---> Started ubar calculations
# t:  1902
#  ---> Started ubar calculations
# t:  1903
#  ---> Started ubar calculations
# t:  1904
#  ---> Started ubar calculations
# t:  1905
#  ---> Started ubar calculations
# t:  1906
#  ---> Started ubar calculations
# t:  1907
#  ---> Started ubar calculations
# t:  1908
#  ---> Started ubar calculations
# t:  1909
#  ---> Started ubar calculations
# t:  1910
#  ---> Started ubar calculations
# t:  1911
#  ---> Started ubar calculations
# t:  1912
#  ---> Started ubar calculations
# t:  1913
#  ---> Started ubar calculations
# t:  1914
#  ---> Started ubar calculations
# t:  1915
#  ---> Started ubar calculations
# t:  1916
#  ---> Started ubar calculations
# t:  1917
#  ---> Started ubar calculations
# t:  1918
#  ---> Started ubar calculations
# t:  1919
#  ---> Started ubar calculations
# t:  1920
#  ---> Started ubar calculations
# t:  1921
#  ---> Started ubar calculations
# t:  1922
#  ---> Started ubar calculations
# t:  1923
#  ---> Started ubar calculations
# t:  1924
#  ---> Started ubar calculations
# t:  1925
#  ---> Started ubar calculations
# t:  1926
#  ---> Started ubar calculations
# t:  1927
#  ---> Started ubar calculations
# t:  1928
#  ---> Started ubar calculations
# t:  1929
#  ---> Started ubar calculations
# t:  1930
#  ---> Started ubar calculations
# t:  1931
#  ---> Started ubar calculations
# t:  1932
#  ---> Started ubar calculations
# t:  1933
#  ---> Started ubar calculations
# t:  1934
#  ---> Started ubar calculations
# t:  1935
#  ---> Started ubar calculations
# t:  1936
#  ---> Started ubar calculations
# t:  1937
#  ---> Started ubar calculations
# t:  1938
#  ---> Started ubar calculations
# t:  1939
#  ---> Started ubar calculations
# t:  1940
#  ---> Started ubar calculations
# t:  1941
#  ---> Started ubar calculations
# t:  1942
#  ---> Started ubar calculations
# t:  1943
#  ---> Started ubar calculations
# t:  1944
#  ---> Started ubar calculations
# t:  1945
#  ---> Started ubar calculations
# t:  1946
#  ---> Started ubar calculations
# t:  1947
#  ---> Started ubar calculations
# t:  1948
#  ---> Started ubar calculations
# t:  1949
#  ---> Started ubar calculations
# t:  1950
#  ---> Started ubar calculations
# t:  1951
#  ---> Started ubar calculations
# t:  1952
#  ---> Started ubar calculations
# t:  1953
#  ---> Started ubar calculations
# t:  1954
#  ---> Started ubar calculations
# t:  1955
#  ---> Started ubar calculations
# t:  1956
#  ---> Started ubar calculations
# t:  1957
#  ---> Started ubar calculations
# t:  1958
#  ---> Started ubar calculations
# t:  1959
#  ---> Started ubar calculations
# t:  1960
#  ---> Started ubar calculations
# t:  1961
#  ---> Started ubar calculations
# t:  1962
#  ---> Started ubar calculations
# t:  1963
#  ---> Started ubar calculations
# t:  1964
#  ---> Started ubar calculations
# t:  1965
#  ---> Started ubar calculations
# t:  1966
#  ---> Started ubar calculations
# t:  1967
#  ---> Started ubar calculations
# t:  1968
#  ---> Started ubar calculations
# t:  1969
#  ---> Started ubar calculations
# t:  1970
#  ---> Started ubar calculations
# t:  1971
#  ---> Started ubar calculations
# t:  1972
#  ---> Started ubar calculations
# t:  1973
#  ---> Started ubar calculations
# t:  1974
#  ---> Started ubar calculations
# t:  1975
#  ---> Started ubar calculations
# t:  1976
#  ---> Started ubar calculations
# t:  1977
#  ---> Started ubar calculations
# t:  1978
#  ---> Started ubar calculations
# t:  1979
#  ---> Started ubar calculations
# t:  1980
#  ---> Started ubar calculations
# t:  1981
#  ---> Started ubar calculations
# t:  1982
#  ---> Started ubar calculations
# t:  1983
#  ---> Started ubar calculations
# t:  1984
#  ---> Started ubar calculations
# t:  1985
#  ---> Started ubar calculations
# t:  1986
#  ---> Started ubar calculations
# t:  1987
#  ---> Started ubar calculations
# t:  1988
#  ---> Started ubar calculations
# t:  1989
#  ---> Started ubar calculations
# t:  1990
#  ---> Started ubar calculations
# t:  1991
#  ---> Started ubar calculations
# t:  1992
#  ---> Started ubar calculations
# t:  1993
#  ---> Started ubar calculations
# t:  1994
#  ---> Started ubar calculations
# t:  1995
#  ---> Started ubar calculations
# t:  1996
#  ---> Started ubar calculations
# t:  1997
#  ---> Started ubar calculations
# t:  1998
#  ---> Started ubar calculations
# t:  1999
#  ---> Started ubar calculations
# t:  2000
#  ---> Started ubar calculations
# t:  2001
#  ---> Started ubar calculations
# t:  2002
#  ---> Started ubar calculations
# t:  2003
#  ---> Started ubar calculations
# t:  2004
#  ---> Started ubar calculations
# t:  2005
#  ---> Started ubar calculations
# t:  2006
#  ---> Started ubar calculations
# t:  2007
#  ---> Started ubar calculations
# t:  2008
#  ---> Started ubar calculations
# t:  2009
#  ---> Started ubar calculations
# t:  2010
#  ---> Started ubar calculations
# t:  2011
#  ---> Started ubar calculations
# t:  2012
#  ---> Started ubar calculations
# t:  2013
#  ---> Started ubar calculations
# t:  2014
#  ---> Started ubar calculations
# t:  2015
#  ---> Started ubar calculations
# t:  2016
#  ---> Started ubar calculations
# t:  2017
#  ---> Started ubar calculations
# t:  2018
#  ---> Started ubar calculations
# t:  2019
#  ---> Started ubar calculations
# t:  2020
#  ---> Started ubar calculations
# t:  2021
#  ---> Started ubar calculations
# t:  2022
#  ---> Started ubar calculations
# t:  2023
#  ---> Started ubar calculations
# t:  2024
#  ---> Started ubar calculations
# t:  2025
#  ---> Started ubar calculations
# t:  2026
#  ---> Started ubar calculations
# t:  2027
#  ---> Started ubar calculations
# t:  2028
#  ---> Started ubar calculations
# t:  2029
#  ---> Started ubar calculations
# t:  2030
#  ---> Started ubar calculations
# t:  2031
#  ---> Started ubar calculations
# t:  2032
#  ---> Started ubar calculations
# t:  2033
#  ---> Started ubar calculations
# t:  2034
#  ---> Started ubar calculations
# t:  2035
#  ---> Started ubar calculations
# t:  2036
#  ---> Started ubar calculations
# t:  2037
#  ---> Started ubar calculations
# t:  2038
#  ---> Started ubar calculations
# t:  2039
#  ---> Started ubar calculations
# t:  2040
#  ---> Started ubar calculations
# t:  2041
#  ---> Started ubar calculations
# t:  2042
#  ---> Started ubar calculations
# t:  2043
#  ---> Started ubar calculations
# t:  2044
#  ---> Started ubar calculations
# t:  2045
#  ---> Started ubar calculations
# t:  2046
#  ---> Started ubar calculations
# t:  2047
#  ---> Started ubar calculations
# t:  2048
#  ---> Started ubar calculations
# t:  2049
#  ---> Started ubar calculations
# t:  2050
#  ---> Started ubar calculations
# t:  2051
#  ---> Started ubar calculations
# t:  2052
#  ---> Started ubar calculations
# t:  2053
#  ---> Started ubar calculations
# t:  2054
#  ---> Started ubar calculations
# t:  2055
#  ---> Started ubar calculations
# t:  2056
#  ---> Started ubar calculations
# t:  2057
#  ---> Started ubar calculations
# t:  2058
#  ---> Started ubar calculations
# t:  2059
#  ---> Started ubar calculations
# t:  2060
#  ---> Started ubar calculations
# t:  2061
#  ---> Started ubar calculations
# t:  2062
#  ---> Started ubar calculations
# t:  2063
#  ---> Started ubar calculations
# t:  2064
#  ---> Started ubar calculations
# t:  2065
#  ---> Started ubar calculations
# t:  2066
#  ---> Started ubar calculations
# t:  2067
#  ---> Started ubar calculations
# t:  2068
#  ---> Started ubar calculations
# t:  2069
#  ---> Started ubar calculations
# t:  2070
#  ---> Started ubar calculations
# t:  2071
#  ---> Started ubar calculations
# t:  2072
#  ---> Started ubar calculations
# t:  2073
#  ---> Started ubar calculations
# t:  2074
#  ---> Started ubar calculations

# %%
# Close the netcdfs
nc1.close()
nc2.close()

# %%
# Should probably manually check this calculation before writing to netcdf and assuming it is correct
# print the depths 
zws = dr_out_rho2u_zwpos[100,:,180,480]
print('zws: ', zws)

# print the distances between the depths (cell thicknesses)
diffs = np.diff(zws)
print('\ndiffs: ', diffs)

# Print the currents at these depths 
curr = u_currents.u[100,:,180,480].values
print('\ncurrents: ', curr)

ubrr = np.sum(diffs*curr)/np.sum(diffs)
print('\nubrr: ', ubrr)

print('\ncalculated ubrr: ', ubar_interp1[100,180,480])

# It looks like it is working as expected! Woohoo!
